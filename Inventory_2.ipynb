# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashrijainar1-web/intern-eligibility-/blob/main/Inventory_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Inventory Reorder Checker

n = int(input("Enter number of products: "))

for i in range(1, n + 1):
    stock = int(input(f"Enter stock for Product {i}: "))

    if stock < 20:
        print(f"Product {i}: Reorder Required")
    else:
        print(f"Product {i}: Stock Sufficient")
# Out:
# Enter number of products: 3
# Enter stock for Product 1: 10
# Product 1: Reorder Required
# Enter stock for Product 2: 25
# Product 2: Stock Sufficient
# Enter stock for Product 3: 5
# Product 3: Reorder Required
