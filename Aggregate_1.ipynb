# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyashrijainar1-web/intern-eligibility-/blob/main/Aggregate_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Daily Sales Aggregator

days = int(input("Enter number of days: "))

total_sales = 0

for i in range(1, days + 1):
    sale = float(input(f"Enter sales for day {i}: "))
    total_sales += sale

average_sales = total_sales / days

print("\nTotal Sales:", total_sales)
print("Average Sales:", average_sales)
# Out:
# Enter number of days: 3
# Enter sales for day 1: 1000
# Enter sales for day 2: 1500
# Enter sales for day 3: 2000
#
# Total Sales: 4500.0
# Average Sales: 1500.0
